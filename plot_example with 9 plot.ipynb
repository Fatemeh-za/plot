# %%
import pandas as pd
surveys_df = pd.read_csv("Downloads/surveys.csv",
                         keep_default_na=False, na_values=[""])
surveys_df
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0              1      7   16  1977        2         NL    M             32.0
# 1              2      7   16  1977        3         NL    M             33.0
# 2              3      7   16  1977        2         DM    F             37.0
# 3              4      7   16  1977        7         DM    M             36.0
# 4              5      7   16  1977        3         DM    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 35544     NaN
# 35545     NaN
# 35546    14.0
# 35547    51.0
# 35548     NaN
#
# [35549 rows x 9 columns]

# %%
species_df = pd.read_csv("Downloads/species.csv",
                         keep_default_na=False, na_values=[""])
species_df
# Out:
#    species_id             genus          species     taxa
# 0          AB        Amphispiza        bilineata     Bird
# 1          AH  Ammospermophilus          harrisi   Rodent
# 2          AS        Ammodramus       savannarum     Bird
# 3          BA           Baiomys          taylori   Rodent
# 4          CB   Campylorhynchus  brunneicapillus     Bird
# 5          CM       Calamospiza      melanocorys     Bird
# 6          CQ        Callipepla         squamata     Bird
# 7          CS          Crotalus       scutalatus  Reptile
# 8          CT     Cnemidophorus           tigris  Reptile
# 9          CU     Cnemidophorus        uniparens  Reptile
# 10         CV          Crotalus          viridis  Reptile
# 11         DM         Dipodomys         merriami   Rodent
# 12         DO         Dipodomys            ordii   Rodent
# 13         DS         Dipodomys      spectabilis   Rodent
# 14         DX         Dipodomys              sp.   Rodent
# 15         EO           Eumeces        obsoletus  Reptile
# 16         GS          Gambelia            silus  Reptile
# 17         NL           Neotoma         albigula   Rodent
# 18         NX           Neotoma              sp.   Rodent
# 19         OL         Onychomys      leucogaster   Rodent
# 20         OT         Onychomys         torridus   Rodent
# 21         OX         Onychomys              sp.   Rodent
# 22         PB       Chaetodipus          baileyi   Rodent
# 23         PC            Pipilo        chlorurus     Bird
# 24         PE        Peromyscus         eremicus   Rodent
# 25         PF       Perognathus           flavus   Rodent
# 26         PG         Pooecetes        gramineus     Bird
# 27         PH       Perognathus         hispidus   Rodent
# 28         PI       Chaetodipus      intermedius   Rodent
# 29         PL        Peromyscus         leucopus   Rodent
# 30         PM        Peromyscus      maniculatus   Rodent
# 31         PP       Chaetodipus     penicillatus   Rodent
# 32         PU            Pipilo           fuscus     Bird
# 33         PX       Chaetodipus              sp.   Rodent
# 34         RF   Reithrodontomys       fulvescens   Rodent
# 35         RM   Reithrodontomys        megalotis   Rodent
# 36         RO   Reithrodontomys         montanus   Rodent
# 37         RX   Reithrodontomys              sp.   Rodent
# 38         SA        Sylvilagus        audubonii   Rabbit
# 39         SB          Spizella          breweri     Bird
# 40         SC        Sceloporus           clarki  Reptile
# 41         SF          Sigmodon      fulviventer   Rodent
# 42         SH          Sigmodon         hispidus   Rodent
# 43         SO          Sigmodon     ochrognathus   Rodent
# 44         SS      Spermophilus        spilosoma   Rodent
# 45         ST      Spermophilus     tereticaudus   Rodent
# 46         SU        Sceloporus        undulatus  Reptile
# 47         SX          Sigmodon              sp.   Rodent
# 48         UL            Lizard              sp.  Reptile
# 49         UP            Pipilo              sp.     Bird
# 50         UR            Rodent              sp.   Rodent
# 51         US           Sparrow              sp.     Bird
# 52         ZL       Zonotrichia       leucophrys     Bird
# 53         ZM           Zenaida         macroura     Bird

# %%
survey_sub = surveys_df.head(10)

survey_sub_last10 = surveys_df.tail(10)

survey_sub_last10 = survey_sub_last10.reset_index(drop=True)

# %%
vertical_stack = pd.concat([survey_sub, survey_sub_last10], axis=0)

horizontal_stack = pd.concat([survey_sub, survey_sub_last10], axis=1)

# %%
vertical_stack
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL    M             32.0
# 1          2      7   16  1977        3         NL    M             33.0
# 2          3      7   16  1977        2         DM    F             37.0
# 3          4      7   16  1977        7         DM    M             36.0
# 4          5      7   16  1977        3         DM    M             35.0
# 5          6      7   16  1977        1         PF    M             14.0
# 6          7      7   16  1977        2         PE    F              NaN
# 7          8      7   16  1977        1         DM    M             37.0
# 8          9      7   16  1977        1         DM    F             34.0
# 9         10      7   16  1977        6         PF    F             20.0
# 0      35540     12   31  2002       15         PB    F             26.0
# 1      35541     12   31  2002       15         PB    F             24.0
# 2      35542     12   31  2002       15         PB    F             26.0
# 3      35543     12   31  2002       15         PB    F             27.0
# 4      35544     12   31  2002       15         US  NaN              NaN
# 5      35545     12   31  2002       15         AH  NaN              NaN
# 6      35546     12   31  2002       15         AH  NaN              NaN
# 7      35547     12   31  2002       10         RM    F             15.0
# 8      35548     12   31  2002        7         DO    M             36.0
# 9      35549     12   31  2002        5        NaN  NaN              NaN
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 0    23.0
# 1    31.0
# 2    29.0
# 3    34.0
# 4     NaN
# 5     NaN
# 6     NaN
# 7    14.0
# 8    51.0
# 9     NaN

# %%
vertical_stack.reset_index()
# Out:
#     index  record_id  month  day  year  plot_id species_id  sex  \
# 0       0          1      7   16  1977        2         NL    M
# 1       1          2      7   16  1977        3         NL    M
# 2       2          3      7   16  1977        2         DM    F
# 3       3          4      7   16  1977        7         DM    M
# 4       4          5      7   16  1977        3         DM    M
# 5       5          6      7   16  1977        1         PF    M
# 6       6          7      7   16  1977        2         PE    F
# 7       7          8      7   16  1977        1         DM    M
# 8       8          9      7   16  1977        1         DM    F
# 9       9         10      7   16  1977        6         PF    F
# 10      0      35540     12   31  2002       15         PB    F
# 11      1      35541     12   31  2002       15         PB    F
# 12      2      35542     12   31  2002       15         PB    F
# 13      3      35543     12   31  2002       15         PB    F
# 14      4      35544     12   31  2002       15         US  NaN
# 15      5      35545     12   31  2002       15         AH  NaN
# 16      6      35546     12   31  2002       15         AH  NaN
# 17      7      35547     12   31  2002       10         RM    F
# 18      8      35548     12   31  2002        7         DO    M
# 19      9      35549     12   31  2002        5        NaN  NaN
#
#     hindfoot_length  weight
# 0              32.0     NaN
# 1              33.0     NaN
# 2              37.0     NaN
# 3              36.0     NaN
# 4              35.0     NaN
# 5              14.0     NaN
# 6               NaN     NaN
# 7              37.0     NaN
# 8              34.0     NaN
# 9              20.0     NaN
# 10             26.0    23.0
# 11             24.0    31.0
# 12             26.0    29.0
# 13             27.0    34.0
# 14              NaN     NaN
# 15              NaN     NaN
# 16              NaN     NaN
# 17             15.0    14.0
# 18             36.0    51.0
# 19              NaN     NaN

# %%
survey_sub = surveys_df.head(10)

species_sub = species_df.copy()

# %%
survey_sub.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
species_sub.columns
# Out:
# Index(['species_id', 'genus', 'species', 'taxa'], dtype='object')

# %%
merged_inner = pd.merge(left=survey_sub, right=species_sub, left_on='species_id', right_on='species_id')

merged_inner.shape
merged_inner
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          8      7   16  1977        1         DM   M             37.0
# 6          9      7   16  1977        1         DM   F             34.0
# 7          6      7   16  1977        1         PF   M             14.0
# 8         10      7   16  1977        6         PF   F             20.0
# 9          7      7   16  1977        2         PE   F              NaN
#
#    weight        genus   species    taxa
# 0     NaN      Neotoma  albigula  Rodent
# 1     NaN      Neotoma  albigula  Rodent
# 2     NaN    Dipodomys  merriami  Rodent
# 3     NaN    Dipodomys  merriami  Rodent
# 4     NaN    Dipodomys  merriami  Rodent
# 5     NaN    Dipodomys  merriami  Rodent
# 6     NaN    Dipodomys  merriami  Rodent
# 7     NaN  Perognathus    flavus  Rodent
# 8     NaN  Perognathus    flavus  Rodent
# 9     NaN   Peromyscus  eremicus  Rodent

# %%
merged_left = pd.merge(left=survey_sub, right=species_sub, how='left', left_on='species_id', right_on='species_id')
merged_left
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight        genus   species    taxa
# 0     NaN      Neotoma  albigula  Rodent
# 1     NaN      Neotoma  albigula  Rodent
# 2     NaN    Dipodomys  merriami  Rodent
# 3     NaN    Dipodomys  merriami  Rodent
# 4     NaN    Dipodomys  merriami  Rodent
# 5     NaN  Perognathus    flavus  Rodent
# 6     NaN   Peromyscus  eremicus  Rodent
# 7     NaN    Dipodomys  merriami  Rodent
# 8     NaN    Dipodomys  merriami  Rodent
# 9     NaN  Perognathus    flavus  Rodent

# %%
merged_left[ pd.isnull(merged_left.genus) ]
# Out:
# Empty DataFrame
# Columns: [record_id, month, day, year, plot_id, species_id, sex, hindfoot_length, weight, genus, species, taxa]
# Index: []

# %%
# %matplotlib inline
import plotnine as p9

# %%
surveys_complete = pd.read_csv('Downloads/surveys.csv')
surveys_complete = surveys_complete.dropna()

# %%
(p9.ggplot(data=surveys_complete,mapping=p9.aes(x='weight', y='hindfoot_length'))+ p9.geom_point())
# Out:
# <ggplot: (108359040976)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='plot_id'))
    + p9.geom_bar()
)
# Out:
# <ggplot: (108361840240)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length'))
    + p9.geom_point(alpha=0.1)
)
# Out:
# <ggplot: (108360280378)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
)
# Out:
# <ggplot: (108360120182)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length'))
    + p9.geom_point(alpha=0.1, color='blue')
)
# Out:
# <ggplot: (108360309309)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length', color='species_id'))
    + p9.geom_point(alpha=0.6)
    + p9.xlab("Weight (g)")
)
# Out:
# <ggplot: (108359038239)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length', color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.xlab("Weight (g)")
    + p9.scale_x_log10()
)
# Out:
# <ggplot: (108361863668)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length', color='sex'))
    + p9.geom_point(alpha=0.1)
    + p9.xlab("Weight (g)")
    + p9.scale_x_log10()
    + p9.theme_bw()
    + p9.theme(text=p9.element_text(size=16))
)
# Out:
# <ggplot: (108363446513)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='species_id',
                          y='weight'))
    + p9.geom_boxplot()
)
# Out:
# <ggplot: (108365450075)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='species_id',
                          y='weight'))
    + p9.geom_jitter(alpha=0.2)
    + p9.geom_boxplot(alpha=0.)
)
# Out:
# <ggplot: (108362178521)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length', color='species_id'))
    + p9.geom_violin(alpha=0.1)
    + p9.xlab("Weight (g)")
    + p9.scale_x_log10()+ p9.scale_y_log10()
    + p9.theme_bw()
    + p9.theme(text=p9.element_text(size=16))
)
# Out:
# C:\Users\FATEMEH\anaconda3\lib\site-packages\plotnine\positions\position.py:202: PlotnineWarning: position_dodge requires non-overlapping x intervals
# <ggplot: (108365425619)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='species_id',
                          y='weight',
                          color='factor(plot_id)'))
    + p9.geom_jitter(alpha=0.3)
    + p9.geom_violin(alpha=0, color="0.7")
    + p9.scale_y_log10()
)
# Out:
# <ggplot: (108359011015)>

# %%
yearly_counts = surveys_complete.groupby(['year', 'species_id'])['species_id'].count()
yearly_counts
# Out:
# year  species_id
# 1977  DM            181
#       DO             12
#       DS             29
#       OL              1
#       OX              2
#                    ...
# 2002  PP            375
#       RM             20
#       RO              7
#       SF              5
#       SH              9
# Name: species_id, Length: 332, dtype: int64

# %%
yearly_counts = yearly_counts.reset_index(name='counts')
yearly_counts
# Out:
#      year species_id  counts
# 0    1977         DM     181
# 1    1977         DO      12
# 2    1977         DS      29
# 3    1977         OL       1
# 4    1977         OX       2
# ..    ...        ...     ...
# 327  2002         PP     375
# 328  2002         RM      20
# 329  2002         RO       7
# 330  2002         SF       5
# 331  2002         SH       9
#
# [332 rows x 3 columns]

# %%
(p9.ggplot(data=yearly_counts,
           mapping=p9.aes(x='year',
                          y='counts',
                          color='species_id'))
    + p9.geom_line()
)
# Out:
# <ggplot: (108360356834)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.facet_wrap("sex")
)
# Out:
# <ggplot: (108359067956)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.facet_wrap("plot_id")
)
# Out:
# <ggplot: (108360365578)>

# %%
survey_2000 = surveys_complete[surveys_complete["year"].isin([2000, 2001])]

(p9.ggplot(data=survey_2000,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.facet_grid("year ~ sex")
)
# Out:
# <ggplot: (108361737900)>

# %%
my_custom_theme = p9.theme(axis_text_x = p9.element_text(color="grey", size=10,
                                                         angle=90, hjust=.5),
                           axis_text_y = p9.element_text(color="grey", size=10))
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='factor(year)'))
    + p9.geom_bar()
    + my_custom_theme
)
# Out:
# <ggplot: (108361574202)>

# %%
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='factor(year)'))
    + p9.geom_bar()
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (108362263721)>

# %%
animals = ['lion', 'tiger', 'crocodile', 'vulture', 'hippo']
for creature in animals:
    pass

# %%
import os

os.mkdir('data/yearly_filess')

# %%
os.listdir('data')
# Out:
# ['fashion', 'MNIST', 'yearly_files', 'yearly_filess']

# %%
import pandas as pd


surveys_df = pd.read_csv('Downloads/surveys.csv')


surveys2002 = surveys_df[surveys_df.year == 2002]


surveys2002.to_csv('data/yearly_filess/surveys2002.csv')

# %%
surveys_df['year']
# Out:
# 0        1977
# 1        1977
# 2        1977
# 3        1977
# 4        1977
#          ...
# 35544    2002
# 35545    2002
# 35546    2002
# 35547    2002
# 35548    2002
# Name: year, Length: 35549, dtype: int64

# %%
surveys_df['year'].unique()
# Out:
# array([1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002], dtype=int64)

# %%
for year in surveys_df['year'].unique():
    filename='data/yearly_filess/surveys' + str(year) + '.csv'
    print(filename)
# Out:
# data/yearly_filess/surveys1977.csv
# data/yearly_filess/surveys1978.csv
# data/yearly_filess/surveys1979.csv
# data/yearly_filess/surveys1980.csv
# data/yearly_filess/surveys1981.csv
# data/yearly_filess/surveys1982.csv
# data/yearly_filess/surveys1983.csv
# data/yearly_filess/surveys1984.csv
# data/yearly_filess/surveys1985.csv
# data/yearly_filess/surveys1986.csv
# data/yearly_filess/surveys1987.csv
# data/yearly_filess/surveys1988.csv
# data/yearly_filess/surveys1989.csv
# data/yearly_filess/surveys1990.csv
# data/yearly_filess/surveys1991.csv
# data/yearly_filess/surveys1992.csv
# data/yearly_filess/surveys1993.csv
# data/yearly_filess/surveys1994.csv
# data/yearly_filess/surveys1995.csv
# data/yearly_filess/surveys1996.csv
# data/yearly_filess/surveys1997.csv
# data/yearly_filess/surveys1998.csv
# data/yearly_filess/surveys1999.csv
# data/yearly_filess/surveys2000.csv
# data/yearly_filess/surveys2001.csv
# data/yearly_filess/surveys2002.csv

# %%
# Load the data into a DataFrame
surveys_df = pd.read_csv('Downloads/surveys.csv')

for year in surveys_df['year'].unique():

    # Select data for the year
    surveys_year = surveys_df[surveys_df.year == year]

    # Write the new DataFrame to a CSV file
    filename = 'data/yearly_filess/surveys' + str(year) + '.csv'
    surveys_year.to_csv(filename)
